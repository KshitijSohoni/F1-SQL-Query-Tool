# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

df=pd.read_csv('Formula1_2023season_raceResults.csv')
df
# Out:
#          Track Position  No           Driver                          Team  \
# 0      Bahrain        1   1   Max Verstappen    Red Bull Racing Honda RBPT
# 1      Bahrain        2  11     Sergio Perez    Red Bull Racing Honda RBPT
# 2      Bahrain        3  14  Fernando Alonso  Aston Martin Aramco Mercedes
# 3      Bahrain        4  55     Carlos Sainz                       Ferrari
# 4      Bahrain        5  44   Lewis Hamilton                      Mercedes
# ..         ...      ...  ..              ...                           ...
# 435  Abu Dhabi       16   2   Logan Sargeant             Williams Mercedes
# 436  Abu Dhabi       17  24      Guanyu Zhou            Alfa Romeo Ferrari
# 437  Abu Dhabi       18  55     Carlos Sainz                       Ferrari
# 438  Abu Dhabi       19  77  Valtteri Bottas            Alfa Romeo Ferrari
# 439  Abu Dhabi       20  20  Kevin Magnussen                  Haas Ferrari
#
# ...

# %%
from sqlalchemy import create_engine, MetaData, Table, select
import pandas as pd

db_path = '/content/database.db'

engine = create_engine(f"sqlite:///{db_path}")

# %%
metadata = MetaData()
metadata.reflect(bind=engine)

# %%
from sqlalchemy import select

F1Data = Table("F1Data", metadata, autoload_with=engine)

query = F1Data.select().limit(10)
with engine.connect() as connection:
    result = connection.execute(query)
    for row in result:
        print(row)
# Out:
# ('Bahrain', '1', 1, 'Max Verstappen', 'Red Bull Racing Honda RBPT', 1, 57, '1:33:56.736', 25, 'No', '1:36.236')
# ('Bahrain', '2', 11, 'Sergio Perez', 'Red Bull Racing Honda RBPT', 2, 57, '+11.987', 18, 'No', '1:36.344')
# ('Bahrain', '3', 14, 'Fernando Alonso', 'Aston Martin Aramco Mercedes', 5, 57, '+38.637', 15, 'No', '1:36.156')
# ('Bahrain', '4', 55, 'Carlos Sainz', 'Ferrari', 4, 57, '+48.052', 12, 'No', '1:37.130')
# ('Bahrain', '5', 44, 'Lewis Hamilton', 'Mercedes', 7, 57, '+50.977', 10, 'No', '1:36.546')
# ('Bahrain', '6', 18, 'Lance Stroll', 'Aston Martin Aramco Mercedes', 8, 57, '+54.502', 8, 'No', '1:36.546')
# ('Bahrain', '7', 63, 'George Russell', 'Mercedes', 6, 57, '+55.873', 6, 'No', '1:37.221')
# ('Bahrain', '8', 77, 'Valtteri Bottas', 'Alfa Romeo Ferrari', 12, 57, '+72.647', 4, 'No', '1:37.379')
# ('Bahrain', '9', 10, 'Pierre Gasly', 'Alpine Renault', 20, 57, '+73.753', 2, 'No', '1:35.068')
# ...

# %%
# !pip install langchain langchain-experimental pymysql transformers accelerate langchain-google-genai pillow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 975.5/975.5 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.7/202.7 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.8/332.8 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 13.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 19.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 718.3/718.3 kB 18.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 16.9 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...

# %%
from google.colab import userdata
# The gemini api key
API_KEY =

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-pro", google_api_key=API_KEY)

# %%
from langchain.utilities import SQLDatabase
from langchain_experimental.sql import SQLDatabaseChain
from langchain.prompts import PromptTemplate
from langchain.prompts.chat import HumanMessagePromptTemplate, ChatPromptTemplate
from langchain.schema import HumanMessage, SystemMessage
from langchain_community.agent_toolkits import create_sql_agent

sqllite_url = "sqlite:///database.db"
db = SQLDatabase.from_uri(sqllite_url, include_tables=["F1Data"])


chain = SQLDatabaseChain.from_llm(llm, db, verbose = True)

final_prompt = ChatPromptTemplate.from_messages(
    [
        ("system",
         """
          You are a helpful AI assistant expert in querying the F1Data table to find answers to user's questions about F1 race and qualifying results.
          F1Data Table:
          The Data table combines both race and qualifying data, structured with columns as follows:
          Track: Location of the race or qualifying session.
          Position: Represents the finishing position in races or qualifying position achieved.
          No: Driver number.
          Driver: Name of the driver.
          Team: Team name or car manufacturer the driver raced for.
          Starting Grid: Initial starting position in races.
          Laps: Number of laps completed during the race or qualifying session.
          Time/Retired: Total race time or status if the driver retired.
          Points: Points scored in races.
          Set Fastest Lap: Indicates if the driver set the fastest lap during the race (Yes/No).
          Fastest Lap Time: Time taken by the driver to set the fastest lap.
         """
         ),
        ("user", "{question}\n ai: "),
    ]
)

# %%
from langchain_community.agent_toolkits import SQLDatabaseToolkit
toolkit = SQLDatabaseToolkit(db=db, llm=llm)

agent_executor = create_sql_agent(
    llm=llm,
    toolkit=toolkit,
    verbose=True,
    handle_parsing_errors=True
)
print(agent_executor.run(final_prompt.format(
        question="Who was third position in Bahrain")))
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# > Entering new SQL Agent Executor chain...
# First, I need to query the F1Data table to find the driver who finished in third position in Bahrain.
# Action: sql_db_query
# Action Input: SELECT Driver FROM F1Data WHERE Track = 'Bahrain' AND Position = 3[('Fernando Alonso',)]The driver who finished in third position in Bahrain is Fernando Alonso.
# Final Answer: Fernando Alonso
#
# > Finished chain.
# Fernando Alonso

# %%
print(agent_executor.run(final_prompt.format(
        question="What is the fastest lap time by Sergio Perez")))
# Out:
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# > Entering new SQL Agent Executor chain...
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 4.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# I need to know the fastest lap time for Sergio Perez.
# Action: sql_db_query_checker
# Action Input: SELECT Fastest_Lap_Time FROM F1Data WHERE Driver = 'Sergio Perez' ORDER BY Fastest_Lap_Time ASC
# ...

# %%
print(agent_executor.run(final_prompt.format(
        question="Who are the drivers of Aston Martin Aramco Mercedes")))
# Out:
# > Entering new SQL Agent Executor chain...
# I need to query the F1Data table to find the drivers of Aston Martin Aramco Mercedes.
# Action: sql_db_query
# Action Input: SELECT DISTINCT Driver FROM F1Data WHERE Team = 'Aston Martin Aramco Mercedes';[('Fernando Alonso',), ('Lance Stroll',)]The drivers of Aston Martin Aramco Mercedes are Fernando Alonso and Lance Stroll.
# Final Answer: Fernando Alonso and Lance Stroll
#
# > Finished chain.
# Fernando Alonso and Lance Stroll
